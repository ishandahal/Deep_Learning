# %%
pip install fastai -U

# %%
pip install nbdev

# %%
import fastai
from fastai.vision.all import *

# %%
# Writing a function that grabs different sized data loaders

def get_data(url, presize, resize):
    path = untar_data(url)
    return DataBlock(blocks=(ImageBlock, CategoryBlock), get_items=get_image_files,
                     splitter=GrandparentSplitter(valid_name='val'),
                     get_y=parent_label, item_tfms=Resize(presize),
                     batch_tfms=[*aug_transforms(min_scale=0.5, size=resize),
                                 Normalize.from_stats(*imagenet_stats)],
                     ).dataloaders(path, bs=128)

# %%
dls = get_data(URLs.IMAGENETTE_160, 160, 128)

# %%
dls.show_batch(max_n=4)

# %%
## Using maxpooling
## Taking the average over x and y axis
def avg_pool(x): return x.mean((2,3))

# %%
## Fully convolutional layer

def block(ni, nf): return ConvLayer(ni, nf, stride=2, )

def get_model():
    return nn.Sequential(
        block(3, 16),       #64X64
        block(16, 32),      #32X32
        block(32, 64),      #16X16
        block(64, 128),     #8X8
        block(128, 256),    #4X4
        nn.AdaptiveAvgPool2d(1),
        Flatten(),
        nn.Linear(256, dls.c))
    # return nn.Sequential(
    #     block(3, 8),
    #     block(8, 16),
    #     block(16, 32),
    #     block(32, 64),
    #     block(64, 100),
    #     block(100, 150),
    #     nn.AdaptiveAvgPool2d(1),
    #     Flatten(),
    #     nn.Linear(150, dls.c))

# %%
def get_learner(m):
    return Learner(dls, m, loss_func=F.cross_entropy, metrics=accuracy).to_fp16()

learn = get_learner(get_model())

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=0.0033113110810518267, lr_steep=0.007585775572806597)

# %%
learn.fit_one_cycle(5, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.897029</td>
#       <td>3.186342</td>
#       <td>0.294522</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.592830</td>
#       <td>1.694120</td>
#       <td>0.460637</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.347762</td>
#       <td>1.301968</td>
#       <td>0.581911</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.142398</td>
#       <td>1.085144</td>
#       <td>0.656306</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.041393</td>
#       <td>0.992835</td>
#       <td>0.685605</td>
#       <td>00:21</td>
#     </tr>
#   </tbody>
# </table>

# %%
class ResBlock(Module):
    def __init__(self, ni, nf):
        self.convs = nn.Sequential(
            ConvLayer(ni, nf),
            ConvLayer(nf, ni, norm_type=NormType.BatchZero))
    
    def forward(self, x):
        return x + self.convs(x)

# %%
## Handling changing shape in the skip connections 

def _conv_block(ni, nf, stride):
    return nn.Sequential(
        ConvLayer(ni, nf, stride=stride),
        ConvLayer(nf, nf, act_cls=None, norm_type=NormType.BatchZero))

# %%
class ResBlock(Module):
    def __init__(self, ni, nf, stride=1):
        self.convs = _conv_block(ni, nf, stride)
        self.idconv = noop if ni==nf else ConvLayer(ni, nf, ks=1, act_cls=None)
        self.pool = noop if stride==1 else nn.AvgPool2d(2, ceil_mode=True)

    def forward(self, x):
        return F.relu(self.convs(x) + self.idconv(self.pool(x)))

# %%
# Let's replace block with ResBlock and try:

def block(ni, nf): return ResBlock(ni, nf, stride=2)
learn = get_learner(get_model())

# %%
learn.fit_one_cycle(5, 3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.974100</td>
#       <td>2.016107</td>
#       <td>0.297070</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.684835</td>
#       <td>1.732823</td>
#       <td>0.444076</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.399838</td>
#       <td>1.264138</td>
#       <td>0.592357</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.193877</td>
#       <td>1.098034</td>
#       <td>0.655796</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.062098</td>
#       <td>1.109119</td>
#       <td>0.648917</td>
#       <td>00:22</td>
#     </tr>
#   </tbody>
# </table>

# %%
## Not much better but we have not taken advantage of the deeper model yet
## Let's do that

def block(ni, nf): return nn.Sequential(ResBlock(ni, nf, stride=2), ResBlock(nf, nf))

# %%
learn = get_learner(get_model())
learn.fit_one_cycle(5, 3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.963917</td>
#       <td>1.866783</td>
#       <td>0.348790</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.626705</td>
#       <td>1.583950</td>
#       <td>0.474395</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.325236</td>
#       <td>1.201862</td>
#       <td>0.617580</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.097996</td>
#       <td>1.047103</td>
#       <td>0.666497</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.933670</td>
#       <td>0.914384</td>
#       <td>0.707006</td>
#       <td>00:23</td>
#     </tr>
#   </tbody>
# </table>

# %%
def _resnet_stem(*sizes):
    return [
            ConvLayer(sizes[i], sizes[i + 1], 3, stride=2 if i==0 else 1)
            for i in range(len(sizes) - 1)
    ] + [nn.MaxPool2d(kernel_size=3, stride=2, padding=1)]

# %%
_resnet_stem(3, 32, 32, 64)
# Out:
# [ConvLayer(
#    (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#    (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (2): ReLU()
#  ), ConvLayer(
#    (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#    (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (2): ReLU()
#  ), ConvLayer(
#    (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#    (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (2): ReLU()
#  ), MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)]

# %%
class ResNet(nn.Sequential):
    def __init__(self, n_out, layers, expansion=1):
        stem = _resnet_stem(3, 32, 32, 64)
        self.block_szs = [64, 64, 128, 256, 512]
        for i in range(1, 5): self.block_szs[i] *= expansion
        blocks = [self._make_layer(*o) for o in enumerate(layers)]
        super().__init__(*stem, *blocks,
                         nn.AdaptiveAvgPool2d(1), Flatten(),
                         nn.Linear(self.block_szs[-1], n_out))
        
    def _make_layer(self, idx, n_layers):
        stride = 1 if idx == 0 else 2
        ch_in, ch_out = self.block_szs[idx : idx + 2]
        return nn.Sequential(*[
                ResBlock(ch_in if i == 0 else ch_out, ch_out, stride if i == 0 else 1)
                for i in range (n_layers)])

# %%
rn = ResNet(dls.c, [2, 2, 2, 2])

# %%
learn = get_learner(rn)
learn.fit_one_cycle(5, 3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.723416</td>
#       <td>2.455906</td>
#       <td>0.354140</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.349033</td>
#       <td>2.465394</td>
#       <td>0.447898</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.079018</td>
#       <td>0.994516</td>
#       <td>0.675924</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.883545</td>
#       <td>0.843243</td>
#       <td>0.732994</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.739558</td>
#       <td>0.721105</td>
#       <td>0.771465</td>
#       <td>00:24</td>
#     </tr>
#   </tbody>
# </table>

# %%
def _conv_block(ni, nf, stride):
    return nn.Sequential(
        ConvLayer(ni, nf // 4, 1),
        ConvLayer(nf // 4, nf // 4, stride=stride),
        ConvLayer(nf // 4, nf, 1, act_cls=None, norm_type=NormType.BatchZero))

# %%
dls = get_data(URLs.IMAGENETTE_320, presize=320, resize=224)

# %%
rn = ResNet(dls.c, [3, 4, 6, 3], 4)

# %%
learn = get_learner(rn)
learn.fit_one_cycle(20, 3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.657922</td>
#       <td>1.745329</td>
#       <td>0.438217</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.399029</td>
#       <td>1.575036</td>
#       <td>0.515414</td>
#       <td>01:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.294784</td>
#       <td>2.657223</td>
#       <td>0.375032</td>
#       <td>01:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.193272</td>
#       <td>1.468008</td>
#       <td>0.563567</td>
#       <td>01:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.079638</td>
#       <td>2.169243</td>
#       <td>0.392357</td>
#       <td>01:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...
